# %% [markdown]
# <a href="https://colab.research.google.com/github/Essieng/Data-Analysis-with-Open-Source/blob/practice/%EC%98%A4%ED%94%88%EC%86%8C%EC%8A%A4_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D_5%EA%B0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 오픈소스 기반 데이터 분석 5강 - 데이터 저장

# %% [markdown]
# ## 5-1 CSV 형식 저장

# %%
import pandas as pd

data = {
    'student_id': [101, 102, 103, 104, 105],
    'database_score': [85, 76, 92, 63, 88],
    'cloudcomputing_score': [78, 82, 95, 70, 84],
    'python_score': [92, 78, 85, 75, 91],
    'watch_rate': [0.95, 0.87, 0.99, 0.80, 0.93]
}
## DataFrame 생성
df = pd.DataFrame(data)


## CSV 형식 저장
df.to_csv("student_analysis.csv", encoding="UTF-8")

# %% [markdown]
# ## 5-2 JSON 형식 저장

# %%
### 라이브러리 임포트
import json
import pandas as pd

data = {
    "이름": "홍길동",
    "나이": 25,
    "거주지": "서울",
    "관심사": ["프로그래밍", "데이터 분석", "여행"]
}

## json.dump를 이용한 저장
with open("output.json", mode="w", encoding="UTF-8") as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

## DataFrame을 이용한 저장
df = pd.DataFrame([data])
df.to_json("output_df.json", orient="records", indent=4, force_ascii=False)

# %% [markdown]
# ## 5-3 Pandas Dataframe 데이터 추출

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터학", "경영학", "농학", "교육학", "영어영문학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}
df = pd.DataFrame(data)
df
## DataFrame 인덱스 출력
print(df.index)
## DataFrame 컬럼 출력
print(df.columns)
## DataFrame 행 출력
print(df.values.tolist())
print(df.values)
## DataFrame 값 출력
print(df.values.flatten())
# Out:
# RangeIndex(start=0, stop=5, step=1)
# Index(['이름', '학년', '학점', '학과', '동아리'], dtype='object')
# [['김철수', 1, 4.2, '컴퓨터학', '프로그래밍'], ['이영희', 2, 3.8, '경영학', '독서토론'], ['박민수', 3, 4.5, '농학', '로봇공학'], ['최지훈', 4, 3.9, '교육학', '봉사활동'], ['정소희', 2, 3.5, '영어영문학', '음악감상']]
# [['김철수' 1 4.2 '컴퓨터학' '프로그래밍']
#  ['이영희' 2 3.8 '경영학' '독서토론']
#  ['박민수' 3 4.5 '농학' '로봇공학']
#  ['최지훈' 4 3.9 '교육학' '봉사활동']
#  ['정소희' 2 3.5 '영어영문학' '음악감상']]
# ['김철수' 1 4.2 '컴퓨터학' '프로그래밍' '이영희' 2 3.8 '경영학' '독서토론' '박민수' 3 4.5 '농학'
#  '로봇공학' '최지훈' 4 3.9 '교육학' '봉사활동' '정소희' 2 3.5 '영어영문학' '음악감상']

# %% [markdown]
# ## 5-4 DataFrame 생성 방법

# %%
import pandas as pd
import json

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## 딕셔너리, csv, json으로 부터 DataFrame 생성
df1 = pd.DataFrame.from_dict(data)
df2 = pd.read_csv("students.csv")
df3 = pd.read_json("students.json")

## 세가지 방법 결과 비교
print(df1.shape)
print(df2.shape)
print(df3.shape)
# Out:
# (5, 5)
# (5, 5)
# (5, 5)

# %% [markdown]
# ## 5-5 DataFrame 저장 방법

# %%
import pandas as pd

data = {
    "이름": ["김철수", "이영희", "박민수", "최지훈", "정소희"],
    "학년": [1, 2, 3, 4, 2],
    "학점": [4.2, 3.8, 4.5, 3.9, 3.5],
    "학과": ["컴퓨터공학", "경영학", "전자공학", "의학", "심리학"],
    "동아리": ["프로그래밍", "독서토론", "로봇공학", "봉사활동", "음악감상"]
}

## Dataframe 생성
df1 = pd.DataFrame(data)

## CSV, JSON 형식으로 저장
df.to_csv("students_scores.csv")
df.to_json("students_scores.json")

## HTML 형식으로 저장
html_table = df.to_html()
with open("students_scores.html", "w") as f:
    f.write(html_table)

# %% [markdown]
# ## 5-6 실습 시나리오

# %% [markdown]
# ## 데이터 수집

# %%
import requests

url = "http://apis.data.go.kr/B552584/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty"
api_key = ''

params = {
    'serviceKey': api_key,
    'returnType': 'json',
    'numOfRows': '100',
    'pageNo': '1',
    'sidoName': '서울',
    'ver': '1.0'
}

## 데이터 수집
response = requests.get(url, params=params)

## 호출 성공/실패 출력
print(response.json())
# Out:
# {'response': {'body': {'totalCount': 40, 'items': [{'so2Grade': '1', 'coFlag': None, 'khaiValue': '88', 'so2Value': '0.003', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '11', 'khaiGrade': '2', 'pm25Value': '5', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.076'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '80', 'so2Value': '0.003', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '17', 'khaiGrade': '2', 'pm25Value': '10', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.015', 'stationName': '한강대로', 'pm10Grade': '1', 'o3Value': '0.066'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '88', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '25', 'khaiGrade': '2', 'pm25Value': '15', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.013', 'stationName': '종로구', 'pm10Grade': '1', 'o3Value': '0.075'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '62', 'so2Value': '0.003', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '24', 'khaiGrade': '2', 'pm25Value': '9', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.017', 'stationName': '청계천로', 'pm10Grade': '1', 'o3Value': '0.044'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '81', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '21', 'khaiGrade': '2', 'pm25Value': '10', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.012', 'stationName': '종로', 'pm10Grade': '1', 'o3Value': '0.066'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '85', 'so2Value': '0.002', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '24', 'khaiGrade': '2', 'pm25Value': '13', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.010', 'stationName': '용산구', 'pm10Grade': '1', 'o3Value': '0.072'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '95', 'so2Value': '0.003', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '25', 'khaiGrade': '2', 'pm25Value': '15', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.015', 'stationName': '광진구', 'pm10Grade': '1', 'o3Value': '0.084'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '94', 'so2Value': '0.002', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '17', 'khaiGrade': '2', 'pm25Value': '11', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.011', 'stationName': '성동구', 'pm10Grade': '1', 'o3Value': '0.082'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '-', 'so2Value': '0.003', 'coValue': '0.4', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '24', 'khaiGrade': None, 'pm25Value': '7', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '2', 'o3Flag': None, 'pm25Grade': None, 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.044', 'stationName': '강변북로', 'pm10Grade': '1', 'o3Value': '0.045'}, {'so2Grade': '1', 'coFlag': None, 'khaiValue': '82',  ...

# %% [markdown]
# ## 데이터 프레임 생성

# %%
import pandas as pd

## requests로부터 response, body, item 항목 읽기
data = response.json()["response"]["body"]["items"]
print(type(data))
print(len(data))
print(data[0])
df = pd.DataFrame(data)
df
# Out:
# <class 'list'>
# 40
# {'so2Grade': '1', 'coFlag': None, 'khaiValue': '88', 'so2Value': '0.003', 'coValue': '0.3', 'pm25Flag': None, 'pm10Flag': None, 'o3Grade': '2', 'pm10Value': '11', 'khaiGrade': '2', 'pm25Value': '5', 'sidoName': '서울', 'no2Flag': None, 'no2Grade': '1', 'o3Flag': None, 'pm25Grade': '1', 'so2Flag': None, 'dataTime': '2025-09-02 17:00', 'coGrade': '1', 'no2Value': '0.008', 'stationName': '중구', 'pm10Grade': '1', 'o3Value': '0.076'}
#    so2Grade coFlag khaiValue so2Value coValue pm25Flag pm10Flag o3Grade  \
# 0         1   None        88    0.003     0.3     None     None       2
# 1         1   None        80    0.003     0.4     None     None       2
# 2         1   None        88    0.002     0.3     None     None       2
# 3         1   None        62    0.003     0.4     None     None       2
# 4         1   None        81    0.002     0.3     None     None       2
# 5         1   None        85    0.002     0.4     None     None       2
# 6         1   None        95    0.003     0.4     None     None       2
# 7         1   None        94    0.002     0.3     None     None       2
# 8         1   None         -    0.003     0.4     None     None       2
# 9         1   None        82    0.003     0.3     None     None       2
# 10        1   None        84    0.002     0.3     None     None       2
# 11        1   None        74    0.003     0.4     None     None       2
# 12        1   None        81    0.003     0.4     None     None       2
# 13        1   None        63    0.002     0.4     None     None       2
# 14        1   None        81    0.003     0.2     None     None       2
# 15        1   None        77    0.002     0.2     None     None       2
# 16        1   None        83    0.002     0.3     None     None       2
# 17        1   None        84    0.002     0.3     None     None       2
# 18        1   None        64    0.002     0.5     None     None       2
# 19     None   통신장애         -        -       -     통신장애     통신장애    None
# 20        1   None         -    0.002     0.3     None     None       2
# 21        1   None        87    0.002     0.3     None     None       2
# 22     None   통신장애         -        -       -     통신장애     통신장애    None
# 23        1   None        73    0.003     0.4     None     None       2
# 24        1   None        96    0.002     0.3     None     None       2
# 25        1   None        80    0.002     0.4     None     None       2
# 26        1   None        96    0.002     0.5     None     통신장애       2
# 27        1   None        92    0.002     0.3     None     None       2
# 28        1   None        91    0.003     0.4     None     None       2
# 29        1   None         -    0.003     0.5     통신장애     통신장애       2
# 30        1   None        73    0.003     0.4     None     None       2
# 31        1   None        87    0.002     0.3     None     None       2
# 32        1   None        96    0.002     0.5     None     None       2
# 33        1   None         -    0.002     0.4     None     None       2
# 34        1   None         -    0.003     0.3     None     None       2
# 35        1   None        79    0.003     0.5     None     None       2
# 36     None   통신장애         -        -       -     통신장애     통신장애    None
# 37        1   None        93    0.002     0.3     None     None       2
# 38        1   None        73    0.002     0.2     None     None       2
# 39        1   None        72    0.002     0.4     None     None       2
#
#    pm10Value khaiGrade  ... no2Grade o3Flag pm25Grade so2Flag  \
# 0         11         2  ...        1   None         1    None
# 1         17         2  ...        1   None         1    None
# 2         25         2  ...        1   None         1    None
# 3         24         2  ...        1   None         1    None
# 4         21         2  ...        1   None         1    None
# 5         24         2  ...        1   None         1    None
# 6         25         2  ...        1   None         1    None
# 7         17         2  ...        1   None         1    None
# 8         24      None  ...        2   None      None    None
# 9         22         2  ...        1   None         1    None
# 10        22         2  ...        1   None         1    None
# 11        20         2  ...        1   None         1    None
# 12         7         2  ...        1   None         1    None
# 13        17         2  ...        2   None         1    None
# 14        13         2  ...        1   None         1    None
# 15        16         2  ...        1   None         1    None
# 16        15         2  ...        1   None         1    None
# 17        12         2  ...        1   None         1    None
# 18        55         2  ...        1   None         1    None
# 19         -      None  ...     None   통신장애      None    통신장애
# 20        18      None  ...        1   None      None    None
# 21        18         2  ...        1   None         1    None
# 22         -      None  ...     None   통신장애      None    통신장애
# 23        16         2  ...        1   None         1    None
# 24        19         2  ...        1   None         1    None
# 25        27         2  ...        2   None         1    None
# 26         -         2  ...        1   None         1    None
# 27        22         2  ...        1   None         1    None
# 28        20         2  ...        1   None         1    None
# 29         -      None  ...        1   None      None    None
# 30        18         2  ...        1   None      None    None
# 31        19         2  ...        1   None         1    None
# 32        27         2  ...        1   None         1    None
# 33        19      None  ...        1   None      None    None
# 34        19      None  ...        1   None         1    None
# 35        36         2  ...        2   None         1    None
# 36         -      None  ...     None   통신장애      None    통신장애
# 37        16         2  ...        1   None         1    None
# 38        15         2  ...        1   None         1    None
# 39        15         2  ...        2   None         1    None
#
#             dataTime coGrade no2Value stationName pm10Grade o3Value
# 0   2025-09-02 17:00       1    0.008          중구         1   0.076
# 1   2025-09-02 17:00       1    0.015        한강대로         1   0.066
# 2   2025-09-02 17:00       1    0.013         종로구         1   0.075
# 3   2025-09-02 17:00       1    0.017        청계천로         1   0.044
# 4   2025-09-02 17:00       1    0.012          종로         1   0.066
# 5   2025-09-02 17:00       1    0.010         용산구         1   0.072
# 6   2025-09-02 17:00       1    0.015         광진구         1   0.084
# 7   2025-09-02 17:00       1    0.011         성동구         1   0.082
# 8   2025-09-02 17:00       1    0.044        강변북로         1   0.045
# 9   2025-09-02 17:00       1    0.013         중랑구         1   0.068
# 10  2025-09-02 17:00       1    0.010        동대문구         1   0.070
# 11  2025-09-02 17:00       1    0.028         홍릉로         1   0.058
# 12  2025-09-02 17:00       1    0.006         성북구         1   0.067
# 13  2025-09-02 17:00       1    0.031         정릉로         1   0.045
# 14  2025-09-02 17:00       1    0.004         도봉구         1   0.067
# 15  2025-09-02 17:00       1    0.005         은평구         1   0.062
# 16  2025-09-02 17:00       1    0.007        서대문구         1   0.069
# 17  2025-09-02 17:00       1    0.009         마포구         1   0.071
# 18  2025-09-02 17:00       1    0.029         신촌로         2   0.046
# 19  2025-09-02 17:00    None        -         강서구      None       -
# 20  2025-09-02 17:00       1    0.020        공항대로      None   0.050
# 21  2025-09-02 17:00       1    0.008         구로구         1   0.074
# 22  2025-09-02 17:00    None        -        영등포구      None       -
# 23  2025-09-02 17:00       1    0.024        영등포로         1   0.057
# 24  2025-09-02 17:00       1    0.009         동작구         1   0.085
# 25  2025-09-02 17:00       1    0.034   동작대로 중앙차로         1   0.065
# 26  2025-09-02 17:00       1    0.009         관악구         1   0.085
# 27  2025-09-02 17:00       1    0.011         강남구         1   0.080
# 28  2025-09-02 17:00       1    0.011         서초구         1   0.079
# 29  2025-09-02 17:00       1    0.009        도산대로      None   0.078
# 30  2025-09-02 17:00       1    0.026        강남대로         1   0.058
# 31  2025-09-02 17:00       1    0.013         송파구         1   0.074
# 32  2025-09-02 17:00       1    0.010         강동구         1   0.085
# 33  2025-09-02 17:00       1    0.021        천호대로         1   0.075
# 34  2025-09-02 17:00       1    0.014         금천구      None   0.090
# 35  2025-09-02 17:00       1    0.047        시흥대로         1   0.056
# 36  2025-09-02 17:00    None        -         강북구      None       -
# 37  2025-09-02 17:00       1    0.008         양천구         1   0.081
# 38  2025-09-02 17:00       1    0.009         노원구         1   0.057
# 39  2025-09-02 17:00       1    0.034         화랑로         1   0.055
#
# [40 rows x 23 columns]

# %% [markdown]
# ## 다양항 형식으로 데이터 저장

# %%
## CSV 형식 데이터 저장
df.to_csv('air_pollution.csv', index=False, encoding='utf-8')

## JSON 형식 데이터 저장
df.to_json("air_pollution.json", indent=4, force_ascii=False)
## EXCEL 형식 데이터 저장
df.to_excel("air_pollution.xlsx", index=False)
## HTML 형식 데이터 저장
df.to_html("air_pollution.html")
